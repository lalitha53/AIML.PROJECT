# %% [markdown]
# <a href="https://colab.research.google.com/github/lalitha53/AIML.PROJECT/blob/main/AIML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv('/content/drive/MyDrive/Heart_Disease_Predictionn.csv')
print(d)
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium  Heart Disease
# 0                          3         3              1
# 1                          0         7              0
# 2                          0         7              1
# 3                          1         7              0
# 4                          1         3              0
# ..                       ...       ...            ...
# 265                        0         7              0
# 266                        0         7              0
# 267                        0         3              0
# 268                        0         6              0
# 269                        3         3              1
#
# [270 rows x 14 columns]

# %%
from matplotlib import pyplot as pt

# %%
x=d['Age']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Sex']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Chest pain type']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['BP']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Cholesterol']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['FBS over 120']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['EKG results']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Max HR']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Exercise angina']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['ST depression']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Slope of ST']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Number of vessels fluro']
y=d['Heart Disease']
pt.plot(x,y)

# %%
x=d['Thallium']
y=d['Heart Disease']
pt.plot(x,y)

# %%
corr_matrix=d.corr()

# %%
import seaborn as sn

# %%
import matplotlib.pyplot as plt

# %%
sn.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
cov_matrix=d.cov()

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(cov_matrix,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
data=pd.read_csv('/content/drive/MyDrive/Heart_Disease_Predictionn.csv')
data.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# 2                        0         7              1
# 3                        1         7              0
# 4                        1         3              0

# %%
y=data.Thallium
x=data.drop('Thallium',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.head()
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 263   49    1                2  130          266             0            0
# 65    57    1                4  150          276             0            2
# 102   49    0                4  130          269             0            0
# 105   48    1                4  124          274             0            2
# 220   54    1                4  110          239             0            0
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 263     171                0            0.6            1
# 65      112                1            0.6            2
# 102     163                0            0.0            1
# 105     166                0            0.5            2
# 220     126                1            2.8            2
#
#      Number of vessels fluro  Heart Disease
# 263                        0              0
# 65                         1              1
# 102                        0              0
# 105                        0              1
# 220                        1              1

# %%
x_train.shape
# Out:
# (216, 13)

# %%
x_test.head()
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 22    43    1                4  115          303             0            0
# 139   57    1                4  132          207             0            0
# 146   52    1                4  112          230             0            0
# 134   54    1                3  150          232             0            2
# 178   67    1                4  125          254             1            0
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 22      181                0            1.2            2
# 139     168                1            0.0            1
# 146     160                0            0.0            1
# 134     165                0            1.6            1
# 178     163                0            0.2            2
#
#      Number of vessels fluro  Heart Disease
# 22                         0              0
# 139                        0              0
# 146                        1              1
# 134                        0              0
# 178                        2              1

# %%
x_test.shape
# Out:
# (54, 13)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
mm=lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
yp=mm.predict(x_test)

# %%
print(yp)
# Out:
# [7 3 3 3 3 7 7 3 3 3 3 7 3 7 7 3 3 7 3 7 7 3 7 3 7 7 7 7 3 7 3 3 3 7 3 3 7
#  7 7 3 7 3 3 3 7 3 7 3 7 3 3 3 7 3]

# %%
x=d.iloc[:,0:7]
y=d.iloc[:,7:8]
print(x)
print(y)
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# [270 rows x 7 columns]
#      Max HR
# 0       109
# 1       160
# 2       141
# 3       105
# 4       121
# ..      ...
# 265     162
# 266     173
# 267     153
# 268     148
# 269     108
#
# [270 rows x 1 columns]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(yp,y_test))
# Out:
# 0.6296296296296297

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[3,2,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
mm=classifier.fit(x_train,y_train)

# %%
yp=mm.predict(x_test)

# %%
print(yp)
# Out:
# [3 3 3 3 6 3 3 3 3 3 3 7 7 3 7 3 7 7 3 3 3 7 7 3 3 3 7 7 3 3 7 3 3 7 3 3 7
#  3 3 7 7 3 3 3 3 7 7 3 7 3 3 3 6 3]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(yp,y_test))
# Out:
# 0.5555555555555556

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[3,2,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
yp=classifier.predict(x_test)

# %%
print(yp)
# Out:
# [3 3 7 3 3 7 7 3 3 3 7 7 3 7 7 7 3 3 3 7 7 7 7 7 7 7 7 7 3 3 3 3 7 7 3 3 3
#  3 7 3 3 3 7 3 3 3 3 7 7 3 3 7 7 7]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(yp,y_test))
# Out:
# 0.5185185185185185

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[3,2,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
yp=gnb.predict(x_test)

# %%
print(yp)
# Out:
# [3 6 6 6 6 3 6 3 3 3 6 6 7 6 7 3 3 7 3 6 7 6 6 6 6 6 6 6 6 7 3 3 3 6 3 6 6
#  6 6 3 6 3 6 3 7 6 7 3 7 3 3 3 6 6]

# %%
accuracy=accuracy_score(yp,y_test)

# %%
print(accuracy)
# Out:
# 0.48148148148148145

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[3,2,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.svm import SVC

# %%
svm_model=SVC(kernel='linear')

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
yp=svm_model.predict(x_test)

# %%
print(yp)
# Out:
# [3 3 7 3 7 3 7 3 3 3 3 7 7 7 7 3 3 7 3 7 3 3 7 7 7 7 7 7 3 7 3 3 3 7 3 3 7
#  3 7 3 7 3 7 3 7 7 7 3 7 3 3 3 7 7]

# %%
accuracy=accuracy_score(yp,y_test)

# %%
print(accuracy)
# Out:
# 0.6851851851851852

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[3,2,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred)
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
from sklearn import tree
tree.plot_tree(model,filled=True)
# Out:
# [3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 7. 3. 3. 7. 3. 7. 7. 3. 3. 7. 6. 7. 7.
#  7. 7. 3. 7. 7. 3. 3. 3. 3. 7. 3. 3. 7. 7. 3. 3. 7. 3. 3. 3. 3. 7. 7. 3.
#  7. 3. 3. 3. 7. 3.]
# 5.425925925925926
# [Text(0.4112903225806452, 0.95, 'x[12] <= 0.5\nsquared_error = 3.731\nsamples = 216\nvalue = 4.639'),
#  Text(0.1461693548387097, 0.85, 'x[1] <= 0.5\nsquared_error = 2.421\nsamples = 125\nvalue = 3.792'),
#  Text(0.04838709677419355, 0.75, 'x[4] <= 490.5\nsquared_error = 0.542\nsamples = 57\nvalue = 3.14'),
#  Text(0.03225806451612903, 0.65, 'x[4] <= 308.5\nsquared_error = 0.281\nsamples = 56\nvalue = 3.071'),
#  Text(0.016129032258064516, 0.55, 'squared_error = 0.0\nsamples = 49\nvalue = 3.0'),
#  Text(0.04838709677419355, 0.55, 'x[7] <= 142.0\nsquared_error = 1.959\nsamples = 7\nvalue = 3.571'),
#  Text(0.03225806451612903, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.06451612903225806, 0.45, 'squared_error = 0.0\nsamples = 6\nvalue = 3.0'),
#  Text(0.06451612903225806, 0.65, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.2439516129032258, 0.75, 'x[3] <= 121.0\nsquared_error = 3.341\nsamples = 68\nvalue = 4.338'),
#  Text(0.12096774193548387, 0.65, 'x[0] <= 41.5\nsquared_error = 3.688\nsamples = 24\nvalue = 5.25'),
#  Text(0.10483870967741936, 0.55, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.13709677419354838, 0.55, 'x[4] <= 286.0\nsquared_error = 3.521\nsamples = 22\nvalue = 5.455'),
#  Text(0.0967741935483871, 0.45, 'x[7] <= 145.5\nsquared_error = 3.062\nsamples = 18\nvalue = 5.778'),
#  Text(0.06451612903225806, 0.35, 'x[7] <= 141.5\nsquared_error = 3.04\nsamples = 5\nvalue = 4.4'),
#  Text(0.04838709677419355, 0.25, 'x[0] <= 61.0\nsquared_error = 0.25\nsamples = 2\nvalue = 6.5'),
#  Text(0.03225806451612903, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.06451612903225806, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.08064516129032258, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 3.0'),
#  Text(0.12903225806451613, 0.35, 'x[7] <= 165.5\nsquared_error = 2.059\nsamples = 13\nvalue = 6.308'),
#  Text(0.11290322580645161, 0.25, 'squared_error = 0.0\nsamples = 8\nvalue = 7.0'),
#  Text(0.14516129032258066, 0.25, 'x[4] <= 238.0\nsquared_error = 3.36\nsamples = 5\nvalue = 5.2'),
#  Text(0.12903225806451613, 0.15, 'x[4] <= 206.0\nsquared_error = 2.0\nsamples = 3\nvalue = 4.0'),
#  Text(0.11290322580645161, 0.05, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.14516129032258066, 0.05, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.16129032258064516, 0.15, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.1774193548387097, 0.45, 'x[3] <= 114.0\nsquared_error = 3.0\nsamples = 4\nvalue = 4.0'),
#  Text(0.16129032258064516, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.1935483870967742, 0.35, 'squared_error = 0.0\nsamples = 3\nvalue = 3.0'),
#  Text(0.36693548387096775, 0.65, 'x[7] <= 151.0\nsquared_error = 2.452\nsamples = 44\nvalue = 3.841'),
#  Text(0.29838709677419356, 0.55, 'x[2] <= 3.5\nsquared_error = 3.302\nsamples = 13\nvalue = 4.923'),
#  Text(0.25806451612903225, 0.45, 'x[9] <= 1.6\nsquared_error = 3.04\nsamples = 10\nvalue = 4.4'),
#  Text(0.22580645161290322, 0.35, 'x[0] <= 41.5\nsquared_error = 1.102\nsamples = 7\nvalue = 3.429'),
#  Text(0.20967741935483872, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.24193548387096775, 0.25, 'squared_error = 0.0\nsamples = 6\nvalue = 3.0'),
#  Text(0.2903225806451613, 0.35, 'x[0] <= 62.5\nsquared_error = 0.222\nsamples = 3\nvalue = 6.667'),
#  Text(0.27419354838709675, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.3064516129032258, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.3387096774193548, 0.45, 'x[4] <= 209.0\nsquared_error = 0.222\nsamples = 3\nvalue = 6.667'),
#  Text(0.3225806451612903, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.3548387096774194, 0.35, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.43548387096774194, 0.55, 'x[3] <= 161.0\nsquared_error = 1.399\nsamples = 31\nvalue = 3.387'),
#  Text(0.41935483870967744, 0.45, 'x[2] <= 1.5\nsquared_error = 0.996\nsamples = 30\nvalue = 3.267'),
#  Text(0.3870967741935484, 0.35, 'x[4] <= 221.5\nsquared_error = 4.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.3709677419354839, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.4032258064516129, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.45161290322580644, 0.35, 'x[0] <= 58.5\nsquared_error = 0.551\nsamples = 28\nvalue = 3.143'),
#  Text(0.43548387096774194, 0.25, 'squared_error = 0.0\nsamples = 25\nvalue = 3.0'),
#  Text(0.46774193548387094, 0.25, 'x[10] <= 1.5\nsquared_error = 3.556\nsamples = 3\nvalue = 4.333'),
#  Text(0.45161290322580644, 0.15, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.4838709677419355, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.45161290322580644, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.6764112903225806, 0.85, 'x[0] <= 59.5\nsquared_error = 3.192\nsamples = 91\nvalue = 5.802'),
#  Text(0.5766129032258065, 0.75, 'x[9] <= 0.05\nsquared_error = 2.269\nsamples = 58\nvalue = 6.276'),
#  Text(0.5, 0.65, 'x[7] <= 145.0\nsquared_error = 3.889\nsamples = 12\nvalue = 5.333'),
#  Text(0.4838709677419355, 0.55, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.5161290322580645, 0.55, 'x[2] <= 3.5\nsquared_error = 3.36\nsamples = 10\nvalue = 5.8'),
#  Text(0.5, 0.45, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.532258064516129, 0.45, 'x[3] <= 117.5\nsquared_error = 1.75\nsamples = 8\nvalue = 6.5'),
#  Text(0.5161290322580645, 0.35, 'x[11] <= 0.5\nsquared_error = 4.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.5, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.532258064516129, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.5483870967741935, 0.35, 'squared_error = 0.0\nsamples = 6\nvalue = 7.0'),
#  Text(0.6532258064516129, 0.65, 'x[4] <= 158.0\nsquared_error = 1.554\nsamples = 46\nvalue = 6.522'),
#  Text(0.6370967741935484, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.6693548387096774, 0.55, 'x[9] <= 3.15\nsquared_error = 1.307\nsamples = 45\nvalue = 6.6'),
#  Text(0.6129032258064516, 0.45, 'x[5] <= 0.5\nsquared_error = 0.472\nsamples = 36\nvalue = 6.833'),
#  Text(0.5806451612903226, 0.35, 'x[9] <= 0.7\nsquared_error = 0.031\nsamples = 31\nvalue = 6.968'),
#  Text(0.5645161290322581, 0.25, 'x[8] <= 0.5\nsquared_error = 0.139\nsamples = 6\nvalue = 6.833'),
#  Text(0.5483870967741935, 0.15, 'squared_error = 0.0\nsamples = 5\nvalue = 7.0'),
#  Text(0.5806451612903226, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.5967741935483871, 0.25, 'squared_error = 0.0\nsamples = 25\nvalue = 7.0'),
#  Text(0.6451612903225806, 0.35, 'x[3] <= 127.5\nsquared_error = 2.4\nsamples = 5\nvalue = 6.0'),
#  Text(0.6290322580645161, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.6612903225806451, 0.25, 'x[2] <= 3.5\nsquared_error = 0.188\nsamples = 4\nvalue = 6.75'),
#  Text(0.6451612903225806, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.6774193548387096, 0.15, 'squared_error = 0.0\nsamples = 3\nvalue = 7.0'),
#  Text(0.7258064516129032, 0.45, 'x[9] <= 3.7\nsquared_error = 3.556\nsamples = 9\nvalue = 5.667'),
#  Text(0.7096774193548387, 0.35, 'x[0] <= 56.5\nsquared_error = 3.84\nsamples = 5\nvalue = 4.6'),
#  Text(0.6935483870967742, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 3.0'),
#  Text(0.7258064516129032, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.7419354838709677, 0.35, 'squared_error = 0.0\nsamples = 4\nvalue = 7.0'),
#  Text(0.7762096774193549, 0.75, 'x[9] <= 0.35\nsquared_error = 3.726\nsamples = 33\nvalue = 4.97'),
#  Text(0.7258064516129032, 0.65, 'x[2] <= 2.5\nsquared_error = 1.25\nsamples = 6\nvalue = 3.5'),
#  Text(0.7096774193548387, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.7419354838709677, 0.55, 'squared_error = 0.0\nsamples = 5\nvalue = 3.0'),
#  Text(0.8266129032258065, 0.65, 'x[7] <= 127.0\nsquared_error = 3.69\nsamples = 27\nvalue = 5.296'),
#  Text(0.7741935483870968, 0.55, 'x[3] <= 141.5\nsquared_error = 2.222\nsamples = 6\nvalue = 3.667'),
#  Text(0.7580645161290323, 0.45, 'squared_error = 0.0\nsamples = 5\nvalue = 3.0'),
#  Text(0.7903225806451613, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8790322580645161, 0.55, 'x[7] <= 152.0\nsquared_error = 3.134\nsamples = 21\nvalue = 5.762'),
#  Text(0.8225806451612904, 0.45, 'x[2] <= 2.0\nsquared_error = 1.243\nsamples = 12\nvalue = 6.583'),
#  Text(0.8064516129032258, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.8387096774193549, 0.35, 'x[4] <= 220.5\nsquared_error = 0.083\nsamples = 11\nvalue = 6.909'),
#  Text(0.8225806451612904, 0.25, 'x[0] <= 62.0\nsquared_error = 0.25\nsamples = 2\nvalue = 6.5'),
#  Text(0.8064516129032258, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8387096774193549, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.8548387096774194, 0.25, 'squared_error = 0.0\nsamples = 9\nvalue = 7.0'),
#  Text(0.9354838709677419, 0.45, 'x[9] <= 1.3\nsquared_error = 3.556\nsamples = 9\nvalue = 4.667'),
#  Text(0.9032258064516129, 0.35, 'x[9] <= 0.8\nsquared_error = 0.222\nsamples = 3\nvalue = 6.667'),
#  Text(0.8870967741935484, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.9193548387096774, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.967741935483871, 0.35, 'x[11] <= 2.5\nsquared_error = 2.222\nsamples = 6\nvalue = 3.667'),
#  Text(0.9516129032258065, 0.25, 'squared_error = 0.0\nsamples = 5\nvalue = 3.0'),
#  Text(0.9838709677419355, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0')]

# %%
 from sklearn.neighbors import KNeighborsRegressor 
model=KNeighborsRegressor() 
model.fit(x_train,y_train) 
y_pred=model.predict(x_test) 
print(y_pred)
# Out:
# [3.8 3.8 5.4 4.6 4.4 6.2 6.2 4.6 3.  3.8 5.4 5.4 4.6 5.4 5.4 5.4 3.8 3.8
#  4.6 5.4 5.4 6.  6.8 6.  6.6 6.  6.8 5.4 4.2 3.8 3.  3.8 6.2 5.4 4.6 4.6
#  4.6 4.6 6.2 3.8 3.8 4.6 6.2 3.  4.6 4.6 4.6 7.  7.  4.4 4.4 6.  6.  6. ]

# %%
from sklearn.metrics import mean_squared_error 
print(mean_squared_error(y_test,y_pred))
# Out:
# 3.9488888888888902

# %%
from sklearn.svm import SVR 
model=SVR() 
model.fit(x_train,y_train) 
y_pred=model.predict(x_test) 
print(y_pred)
# Out:
# [2.97082138 3.11350153 3.13242094 3.19110514 3.0993756  3.54512003
#  3.736306   3.0721979  3.29423805 3.04347627 3.15894027 3.55282511
#  3.06976012 3.75265091 3.4906657  3.36874425 2.91914947 3.39520716
#  3.03621617 3.40543492 3.66491853 3.47702416 3.33278026 3.33077759
#  3.7258397  3.78160179 3.49318821 3.55108471 3.45994328 3.25519663
#  3.0839021  3.1886347  3.40594596 3.69338346 2.97717106 3.08268516
#  3.37109938 3.25130155 3.12923175 3.17093033 3.16171231 3.41221131
#  3.69750463 3.17230781 3.21699194 3.13441095 3.41073382 3.78484838
#  3.59565679 3.13124851 3.3940777  3.57305813 3.40678128 3.61388155]

# %%
from sklearn.metrics import mean_squared_error 
print(mean_squared_error(y_test,y_pred))
# Out:
# 6.1290323135904705
